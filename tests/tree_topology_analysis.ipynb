# %% [markdown]
# # Testing the Prerprocessor Class - Analyzing the Parse Trees

# %%
import sys
import os

# %%
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(root_dir)

# %%
from Preprocessor import Preprocessor

# %%
preprocessor = Preprocessor("../dataset/PIZZA_train.json", "../dataset/PIZZA_dev.json", "../dataset/PIZZA_test.json", 
                            "../dataset/preprocessed_PIZZA_train.json", "../dataset/preprocessed_PIZZA_dev.json", 
                            "../dataset/preprocessed_PIZZA_test.json")

# %%
preprocessor.get_top_trees(metric="depth", dataset_type="train")
# Out:
# Processed 1000 entries...
# Processed 2000 entries...
# Processed 3000 entries...
# Processed 4000 entries...
# Processed 5000 entries...
# Processed 6000 entries...
# Processed 7000 entries...
# Processed 8000 entries...
# Processed 9000 entries...
# Processed 10000 entries...
# Processed 11000 entries...
# Processed 12000 entries...
# Processed 13000 entries...
# Processed 14000 entries...
# Processed 15000 entries...
# Processed 16000 entries...
# Processed 17000 entries...
# Processed 18000 entries...
# Processed 19000 entries...
# Processed 20000 entries...
# Processed 21000 entries...
# Processed 22000 entries...
# Processed 23000 entries...
# Processed 24000 entries...
# Processed 25000 entries...
# Processed 26000 entries...
# Processed 27000 entries...
# Processed 28000 entries...
# Processed 29000 entries...
# Processed 30000 entries...
# Processed 31000 entries...
# Processed 32000 entries...
# Processed 33000 entries...
# Processed 34000 entries...
# ...

# %%
preprocessor.get_top_trees(metric="depth", dataset_type="dev")
# Out:
# Finished processing 348 entries.
# [{'dev.SRC': 'i want a pizza with sausage bacon and no extra cheese',
#   'dev.TOP': '(ORDER i want (PIZZAORDER (NUMBER a ) pizza with (TOPPING sausage ) (TOPPING bacon ) and no (NOT (COMPLEX_TOPPING (QUANTITY extra ) (TOPPING cheese ) ) ) ) )'},
#  {'dev.SRC': 'i would like to try one small ham and pesto pie with no extra cheese',
#   'dev.TOP': '(ORDER i would like to try (PIZZAORDER (NUMBER one ) (SIZE small ) (TOPPING ham ) and (TOPPING pesto ) pie with no (NOT (COMPLEX_TOPPING (QUANTITY extra ) (TOPPING cheese ) ) ) ) )'},
#  {'dev.SRC': 'i prefer a pie with medium size along with ham and sausage but without extra cheese',
#   'dev.TOP': '(ORDER i prefer (PIZZAORDER (NUMBER a ) pie with (SIZE medium ) size along with (TOPPING ham ) and (TOPPING sausage ) but without (NOT (COMPLEX_TOPPING (QUANTITY extra ) (TOPPING cheese ) ) ) ) )'},
#  {'dev.SRC': "i'll try a large pizza that comes with pesto and pineapple but make sure no extra cheese",
# ...

# %%
preprocessor.get_top_trees(metric="size", dataset_type="train")
# Out:
# Processed 1000 entries...
# Processed 2000 entries...
# Processed 3000 entries...
# Processed 4000 entries...
# Processed 5000 entries...
# Processed 6000 entries...
# Processed 7000 entries...
# Processed 8000 entries...
# Processed 9000 entries...
# Processed 10000 entries...
# Processed 11000 entries...
# Processed 12000 entries...
# Processed 13000 entries...
# Processed 14000 entries...
# Processed 15000 entries...
# Processed 16000 entries...
# Processed 17000 entries...
# Processed 18000 entries...
# Processed 19000 entries...
# Processed 20000 entries...
# Processed 21000 entries...
# Processed 22000 entries...
# Processed 23000 entries...
# Processed 24000 entries...
# Processed 25000 entries...
# Processed 26000 entries...
# Processed 27000 entries...
# Processed 28000 entries...
# Processed 29000 entries...
# Processed 30000 entries...
# Processed 31000 entries...
# Processed 32000 entries...
# Processed 33000 entries...
# Processed 34000 entries...
# ...

# %%
preprocessor.get_top_trees(metric="size", dataset_type="dev")
# Out:
# Finished processing 348 entries.
# [{'dev.SRC': 'place an order for six lunch pizzas with sausage six lunch pizzas with pepperoni four lunch pizzas with mushrooms and twelve medium cokes and four medium sprites',
#   'dev.TOP': '(ORDER place an order for (PIZZAORDER (NUMBER six ) (SIZE lunch ) pizzas with (TOPPING sausage ) ) (PIZZAORDER (NUMBER six ) (SIZE lunch ) pizzas with (TOPPING pepperoni ) ) (PIZZAORDER (NUMBER four ) (SIZE lunch ) pizzas with (TOPPING mushrooms ) ) and (DRINKORDER (NUMBER twelve ) (SIZE medium ) (DRINKTYPE cokes ) ) and (DRINKORDER (NUMBER four ) (SIZE medium ) (DRINKTYPE sprites ) ) )'},
#  {'dev.SRC': 'i need to order five large pizzas with pepperoni sausage and green peppers and one small pizza with sausage green peppers and black olives and eight medium cokes and nine medium sprites',
# ...
